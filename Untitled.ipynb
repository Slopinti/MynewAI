# %%
pip install NLTK
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import nltk
#
# ModuleNotFoundError: No module named 'nltk'

# %%
nltk.download
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 nltk.download
#
# NameError: name 'nltk' is not defined

# %%
from nltk import word_tokenizer
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from nltk import word_tokenizer
#
# ImportError: cannot import name 'word_tokenizer' from 'nltk' (C:\Users\Baby\AppData\Local\Programs\Python\Python313\Lib\site-packages\nltk\__init__.py)

# %%
---python -m ipykernel install --name AIvenv --display-name "AIvenv2026"\
